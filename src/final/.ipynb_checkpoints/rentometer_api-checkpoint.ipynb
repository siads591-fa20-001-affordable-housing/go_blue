# %% [markdown]
# # University of Michigan
# ## School of Information
# **Masters of Applied Data Science**<br>
# **Milestone 1**<br>
# <br>
# Affordable Housing Project
# <br><br>
# **Submitted by**<br>
# >Alan Fehsenfeld<br>Koon Leong Ho<br>George Thio

# %%
import numpy as np
import pandas as pd
import time

import requests
import io
import os

from config import basedir
base = basedir()

pd.options.display.html.use_mathjax = False
pd.options.mode.chained_assignment = None  # default='warn'

# %% [markdown]
# ## Summary
# This notebook demonstrates the use of the Rentometer API which we used exclusively to generate rent estimates for a reference list of 547 apartment buildings in Kent County used as the price comparison basis of affordablity for the universe of 227,210 properties in Kent County to determine the MSHDA rent affordability score (0 or 5 points).
#
# After searching for other data sources, the Rentometer API was the only one we found that could take property latitude and longitude coordinates and unit bedroom count as variables and return a rental estimate and the search radius used to calculate the estimate, both required information for the sscoring calculus.

# %% [markdown]
# ## Get Rentometer API key and endpoint

# %%
# Rentometer API Key
key = "k8MO2sfE9sg5536t9MwUnA"

# Rentometer Endpoint
endpoint = "https://www.rentometer.com/api/v1/summary"

# %% [markdown]
# ## Original function to make Rentometer API calls

# %% [markdown]
# As our Rentometer PRO Standard trial and key expired on January 19, 2021, the code cells below are for illustrative purposes only and should not be re-run as they require a valid API key. All the results from the API calls have been saved in `apartments_final.csv` so there is no need to run the function again for Kent County.
#
# Due to debugging, limited API credits and top up issues, and initally undetected throttling by the API, this function had to be run on several several different occasions (and in several different notebooks) after several complimentary credit top-ups to produce the `apartments_final.csv` file which contains the 547 identified apartment buildings in Kent County. This file was then used to populate the `property_level.csv` file with binary affordability score columns indicating whether a subject property is within the required 0.25 miles of a property qualifying for affordable status.
#
# Counterintuitively, we are looking for subject properties that are themselves located near high rent properites which makes them "unaffordable" and hence good candidates for affordable housing -- i.e. qualifying properties receive 5 points on the MSHDA scoring assessment, 0 points otherwise. As shown in the function, the threshold rent levels are $ 1,264, 1,516, 1,751 and 1,954 for 1-4 bedroom homes in Kent County respectively. For simplicity, to preserve API credits, and given no expected loss in accuracy, we made API calls using only 1-bedroom units as a proxy for affordability of all size units in a given building.
#
# Below we show examples of API calls that may involve intermediate processing files not found in the project folder.

# %%
def rentometer(df, br=1):
    ''' Uses the Rentometer API to return a dataframe with maximal rent 
        estimate ($), search radius (mi) and affodabliity assessment (1/0) 
        for apartments in Kent County, MI 
        
    Parameters:
        df: Pandas dataframe (df)
        br: Number of bedrooms (int; 1, 2, 3, 4)'''
    
    # Create new columns
    df[str(br)+"br_rent_estimate"] = None
    df["search_radius"] = None
    df["affordability"] = None
        
    for i in range(len(df)):
        
        # Check number of bedrooms 
        assert type(br) == int and br > 0 and br < 5, "Valid values of br are: 1, 2, 3, 4"
        
        # Get lat/lng
        lat = str(df["PROPERTY LEVEL LATITUDE"].iloc[i])
        lng = str(df["PROPERTY LEVEL LONGITUDE"].iloc[i])
        
        # Set URL string and make API call
        try:
            url = endpoint+"?api_key="+key+"&latitude="+lat+"&longitude="+lng+"&bedrooms="+str(br)
            response = requests.get(url)
            result = response.json()
        except:
            print(response)
            print("Error on row", i)

        # Get rent estimate and search radius
        df[str(br)+"br_rent_estimate"].iloc[i] = result.get("max")
        df["search_radius"] = result.get("radius_miles")
        
        # Check affordability
        if br == 1 and df[str(br)+"br_rent_estimate"].iloc[i] > 1264:
            df["affordability"].iloc[i] = 1
        elif br == 2 and df[str(br)+"br_rent_estimate"].iloc[i] > 1516:
            df["affordability"].iloc[i] = 1
        elif br == 3 and df[str(br)+"br_rent_estimate"].iloc[i] > 1751:
            df["affordability"].iloc[i] = 1
        elif br == 4 and df[str(br)+"br_rent_estimate"].iloc[i] > 1954:
            df["affordability"].iloc[i] = 1
        else:
            df["affordability"].iloc[i] = 0
         
        # Pause to avoid throttling
        time.sleep(10)

    return df

# %% [markdown]
# ## Note on API calls and MSHDA afforablity scoring

# %% [markdown]
# ve intermediate processing files not present in the project folder.

# %% [markdown]
# ## Run function on first 50 apartments

# %%
apartments2_df_50 = rentometer(df=apt2_df_50, br=1)

# %%
apartments2_df_50
# Out:
#     Unnamed: 0  Unnamed: 0.1  PROPERTY LEVEL LATITUDE  \
# 0           17            17                42.782521
# 1           40            40                42.786286
# 2           68            68                42.789451
# 3           79            79                42.790470
# 4          160           160                42.812479
# 5          206           206                42.813725
# 6          324           324                42.827619
# 7          347           347                42.830008
# 8          348           348                42.830009
# 9          401           401                42.835228
# 10         417           417                42.837326
# 11         652           652                42.850218
# 12         662           662                42.850957
# 13         711           711                42.854217
# 14         759           759                42.858265
# 15         806           806                42.861409
# 16         813           813                42.861628
# 17         815           815                42.861736
# 18         817           817                42.861788
# 19         819           819                42.861831
# 20         875           875                42.864613
# 21         886           886                42.865131
# 22         932           932                42.867314
# 23        1058          1058                42.872824
# 24        1088          1088                42.874656
# 25        1098          1098                42.875342
# 26        1100          1100                42.875510
# 27        1109          1109                42.875910
# 28        1130          1130                42.877068
# 29        1138          1138                42.877450
# 30        1140          1140                42.877557
# 31        1154          1154                42.878408
# 32        1157          1157                42.878463
# 33        1178          1178                42.879298
# 34        1187          1187                42.879515
# 35        1273          1273                42.881625
# 36        1277          1277                42.881757
# 37        1285          1285                42.881881
# 38        1291          1291                42.882081
# 39        1323          1323                42.882657
# 40        1353          1353                42.883040
# 41        1365          1365                42.883116
# 42        1366          1366                42.883127
# 43        1385          1385                42.883255
# 44        1391          1391                42.883276
# 45        1414          1414                42.883385
# 46        1425          1425                42.883532
# 47        1471          1471                42.883990
# 48        1553          1553                42.884439
# 49        1609          1609                42.884962
#
#     PROPERTY LEVEL LONGITUDE  ORIGINAL APN  ind  \
# 0                 -85.502569             1  0.0
# 1                 -85.509398             1  0.0
# 2                 -85.514409             1  0.0
# 3                 -85.513271             1  0.0
# 4                 -85.671510             1  0.0
# 5                 -85.714827             1  0.0
# 6                 -85.660240             1  0.0
# 7                 -85.659792             1  0.0
# 8                 -85.660622             1  0.0
# 9                 -85.625201             1  0.0
# 10                -85.694676             1  0.0
# 11                -85.574948             1  0.0
# 12                -85.640646             1  0.0
# 13                -85.650505             1  0.0
# 14                -85.725425             1  0.0
# 15                -85.648313             1  0.0
# 16                -85.649314             1  0.0
# 17                -85.711440             1  0.0
# 18                -85.648306             1  0.0
# 19                -85.726034             1  0.0
# 20                -85.660744             1  0.0
# 21                -85.567956             1  0.0
# 22                -85.660724             1  0.0
# 23                -85.665443             1  0.0
# 24                -85.612234             1  0.0
# 25                -85.729356             1  0.0
# 26                -85.741891             1  0.0
# 27                -85.599066             1  0.0
# 28                -85.644566             1  0.0
# 29                -85.604610             1  0.0
# 30                -85.617056             1  0.0
# 31                -85.597514             1  0.0
# 32                -85.607371             1  0.0
# 33                -85.602575             1  0.0
# 34                -85.644712             1  0.0
# 35                -85.770042             1  0.0
# 36                -85.621347             1  0.0
# 37                -85.709790             1  0.0
# 38                -85.706656             1  0.0
# 39                -85.598497             1  0.0
# 40                -85.700837             1  0.0
# 41                -85.702687             1  0.0
# 42                -85.702071             1  0.0
# 43                -85.647609             1  0.0
# 44                -85.703296             1  0.0
# 45                -85.701463             1  0.0
# 46                -85.700337             1  0.0
# 47                -85.700906             1  0.0
# 48                -85.627848             1  0.0
# 49                -85.624533             1  0.0
#
#                                               address            type  \
# 0       10010 Crossroads Ct, Caledonia, MI 49316, USA         premise
# 1         301 S Maple St SE, Caledonia, MI 49316, USA  street_address
# 2          203 E Main St SE, Caledonia, MI 49316, USA    beauty_salon
# 3          303 Emmons St SE, Caledonia, MI 49316, USA         premise
# 4         325 84th St SW, Byron Center, MI 49315, USA         premise
# 5   2115 84th St SW Ste A, Byron Center, MI 49315,...   establishment
# 6            146 Lurie St SE, Kentwood, MI 49548, USA  street_address
# 7      146 Coleman St SE, Grand Rapids, MI 49548, USA         premise
# 8      116 Coleman St SE, Grand Rapids, MI 49548, USA         premise
# 9     7115 Kalamazoo Ave SE, Caledonia, MI 49316, USA  street_address
# 10  7032 Marshwood Dr SW, Byron Center, MI 49315, USA  street_address
# 11     3638 Cobblefield Cir, Caledonia, MI 49316, USA  street_address
# 12  960 Woodfield E Dr SE, Grand Rapids, MI 49508,...  street_address
# 13        560 60th St SE, Grand Rapids, MI 49548, USA  street_address
# 14  5892 Bayberry Farms Dr SW, Wyoming, MI 49418, USA  street_address
# 15            670 56th St SE, Kentwood, MI 49548, USA         premise
# 16            620 56th St SE, Kentwood, MI 49548, USA  street_address
# 17       1987 Parkcrest Dr SW, Wyoming, MI 49519, USA  street_address
# 18            660 56th St SE, Kentwood, MI 49548, USA         premise
# 19            2520 56th St SW, Wyoming, MI 49418, USA  street_address
# 20  150 Kellogg Woods Park Dr SE, Grand Rapids, MI...  street_address
# 21         3928 N Rosebud Dr, Kentwood, MI 49512, USA  street_address
# 22  5220 Kellogg Woods Dr SE, Kentwood, MI 49548, USA  street_address
# 23         42 50th St SW, Grand Rapids, MI 49548, USA  street_address
# 24    2135 Sandy Shore Dr SE, Kentwood, MI 49508, USA  street_address
# 25        2600 Woodlake Rd SW, Wyoming, MI 49519, USA  street_address
# 26       4930 Ivanrest Ave SW, Wyoming, MI 49418, USA  street_address
# 27         4844 Breton Rd SE, Kentwood, MI 49508, USA  street_address
# 28   4738 Eastern Ave SE, Grand Rapids, MI 49508, USA  street_address
# 29       4735 N Breton Ct SE, Kentwood, MI 49508, USA  street_address
# 30   4723 Circle Shore Dr SE, Kentwood, MI 49508, USA  street_address
# 31         4751 Walma Ave SE, Kentwood, MI 49512, USA  street_address
# 32     4703 Drummond Blvd SE, Kentwood, MI 49508, USA  street_address
# 33       4634 N Breton Ct SE, Kentwood, MI 49508, USA  street_address
# 34       4650 Eastern Ave SE, Kentwood, MI 49508, USA  street_address
# 35       4325 Wimbledon Dr, Grandville, MI 49418, USA  street_address
# 36        4520 Bowen Blvd SE, Kentwood, MI 49508, USA         premise
# 37  1790 R W Berends Drive Southwest, Wyoming, MI ...  street_address
# 38  1650 R W Berends Drive Southwest, Wyoming, MI ...  street_address
# 39           2718 44th St SE, Kentwood, MI 49512, USA         premise
# 40            1490 44th St SW, Wyoming, MI 49509, USA         premise
# 41            1540 44th St SW, Wyoming, MI 49509, USA         premise
# 42            1536 44th St SW, Wyoming, MI 49509, USA         premise
# 43            702 44th St SE, Kentwood, MI 49548, USA  street_address
# 44            1550 44th St SW, Wyoming, MI 49509, USA  street_address
# 45            1536 44th St SW, Wyoming, MI 49509, USA         premise
# 46            1446 44th St SW, Wyoming, MI 49509, USA  street_address
# 47            1474 44th St SW, Wyoming, MI 49509, USA  street_address
# 48     4350 Norman Dr SE, Grand Rapids, MI 49508, USA  street_address
# 49  4320 Kalamazoo Ave SE, Grand Rapids, MI 49508,...   establishment
#
#     delivery_point_barcode record_type          rdi dpv_match_code  \
# 0             4.931680e+11           H  Residential              D
# 1             4.931690e+11           H  Residential              D
# 2             4.931670e+11           H  Residential              D
# 3             4.931670e+11           H  Residential              D
# 4             4.931590e+11           H  Residential              D
# 5             4.931590e+11           H  Residential              Y
# 6             4.954880e+11           H  Residential              D
# 7             4.954880e+11           H  Residential              D
# 8             4.954880e+11           H  Residential              D
# 9             4.931690e+11           H  Residential              D
# 10            4.931590e+11           H  Residential              D
# 11            4.931690e+11           H  Residential              D
# 12            4.950870e+11           H  Residential              D
# 13            4.954870e+11           H  Residential              D
# 14            4.941890e+11           H  Residential              D
# 15            4.954810e+11           H  Residential              D
# 16            4.954860e+11           H  Residential              D
# 17            4.951990e+11           H  Residential              D
# 18            4.954810e+11           H  Residential              D
# 19            4.941880e+11           H  Residential              D
# 20            4.954810e+11           H  Residential              D
# 21            4.951290e+11           H  Residential              D
# 22            4.954810e+11           H  Residential              D
# 23            4.954860e+11           H  Residential              D
# 24            4.950850e+11           H  Residential              D
# 25            4.951950e+11           H  Residential              D
# 26            4.941890e+11           H  Residential              D
# 27            4.950850e+11           H  Residential              D
# 28            4.950880e+11           H  Residential              D
# 29            4.950850e+11           H  Residential              D
# 30            4.950810e+11           H  Residential              D
# 31            4.951250e+11           H  Residential              D
# 32            4.950810e+11           H  Residential              D
# 33            4.950880e+11           H  Residential              D
# 34            4.950880e+11           H  Residential              D
# 35            4.941830e+11           H  Residential              D
# 36            4.950850e+11           H  Residential              D
# 37            4.951950e+11           H  Residential              D
# 38            4.951950e+11           H  Residential              D
# 39            4.951240e+11           H  Residential              D
# 40            4.950940e+11           H  Residential              D
# 41            4.950940e+11           H  Residential              D
# 42            4.950940e+11           H  Residential              D
# 43            4.954880e+11           H  Residential              D
# 44            4.950940e+11           H  Residential              D
# 45            4.950940e+11           H  Residential              D
# 46            4.950940e+11           H  Residential              D
# 47            4.950940e+11           H  Residential              D
# 48            4.950890e+11           H  Residential              D
# 49            4.950860e+11           H  Residential              D
#
#    dpv_footnotes footnotes 1br_rent_estimate  search_radius affordability
# 0           AAN1    H#L#M#              1305            1.5             1
# 1           AAN1        H#              1305            1.5             1
# 2           AAN1        H#              1305            1.5             1
# 3           AAN1        H#              1305            1.5             1
# 4           AAN1        H#               908            1.5             0
# 5           AABB        N#              1034            1.5             0
# 6           AAN1        H#               908            1.5             0
# 7           AAN1        H#               908            1.5             0
# 8           AAN1        H#               908            1.5             0
# 9           AAN1        H#              1305            1.5             1
# 10          AAN1        H#               930            1.5             0
# 11          AAN1      H#L#              1413            1.5             1
# 12          AAN1      H#N#              1034            1.5             0
# 13          AAN1        H#              1413            1.5             1
# 14          AAN1        H#               930            1.5             0
# 15          AAN1        H#              1034            1.5             0
# 16          AAN1        H#              1034            1.5             0
# 17          AAN1        H#              1000            1.5             0
# 18          AAN1        H#              1034            1.5             0
# 19          AAN1        H#               930            1.5             0
# 20          AAN1        H#              1000            1.5             0
# 21          AAN1      H#L#              1413            1.5             1
# 22          AAN1        H#              1000            1.5             0
# 23          AAN1        H#              1000            1.5             0
# 24          AAN1        H#              1413            1.5             1
# 25          AAN1        H#              1000            1.5             0
# 26          AAN1        H#              1000            1.5             0
# 27          AAN1        H#              1413            1.5             1
# 28          AAN1        H#              1298            1.5             1
# 29          AAN1        H#              1413            1.5             1
# 30          AAN1        H#              1298            1.5             1
# 31          AAN1        H#              1413            1.5             1
# 32          AAN1        H#              1413            1.5             1
# 33          AAN1        H#              1413            1.5             1
# 34          AAN1        H#              1298            1.5             1
# 35          AAN1      H#L#              1000            1.5             0
# 36          AAN1        H#              1298            1.5             1
# 37          AAN1      H#N#              1000            1.5             0
# 38          AAN1      H#N#              1000            1.5             0
# 39          AAN1        H#              1413            1.5             1
# 40          AAN1        H#              1000            1.5             0
# 41          AAN1        H#              1000            1.5             0
# 42          AAN1        H#              1000            1.5             0
# 43          AAN1        H#              1298            1.5             1
# 44          AAN1        H#              1000            1.5             0
# 45          AAN1        H#              1000            1.5             0
# 46          AAN1        H#              1000            1.5             0
# 47          AAN1        H#              1000            1.5             0
# 48          AAN1        H#              1298            1.5             1
# 49          AAN1        H#              1298            1.5             1

# %%
apartments2_df_50.to_csv('apartments2_50.csv')

# %% [markdown]
# ## Run function in batches with remaining API credits (332) to avoid throttling during beta period

# %%
# First batches
for i in [60, 110, 160, 210, 260, 310]:
    batch_df = apt2_df.iloc[i:i+50]
    apartments2_df =  apartments2_df.append(rentometer(batch_df, 1))
    time.sleep(10)

# %%
apartments2_df.tail(1)
# Out:
#      Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  PROPERTY LEVEL LATITUDE  \
# 359        5914          5914             NaN                42.964823
#
#      PROPERTY LEVEL LONGITUDE  ORIGINAL APN  ind  \
# 359                -85.658395             1  0.0
#
#                                              address     type  \
# 359  442 Fountain St NE, Grand Rapids, MI 49503, USA  premise
#
#      delivery_point_barcode record_type          rdi dpv_match_code  \
# 359            4.950360e+11           H  Residential              D
#
#     dpv_footnotes footnotes 1br_rent_estimate  search_radius affordability
# 359          AAN1        H#              1300            0.5             1

# %%
## Export dataframe to csv
apartments2_df.to_csv('apartments2.csv')

# %%
# Last batch
batch_df = apt2_df.iloc[360:392]
apartments2_df =  apartments2_df.append(rentometer(batch_df, 1))

# %%
apartments2_df.tail(1)
# Out:
#      Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  PROPERTY LEVEL LATITUDE  \
# 391        6022          6022             NaN                 42.96764
#
#      PROPERTY LEVEL LONGITUDE  ORIGINAL APN  ind  \
# 391                -85.660629             1  0.0
#
#                                          address     type  \
# 391  329 Lyon St NE, Grand Rapids, MI 49503, USA  premise
#
#      delivery_point_barcode record_type          rdi dpv_match_code  \
# 391            4.950330e+11           H  Residential              D
#
#     dpv_footnotes footnotes 1br_rent_estimate  search_radius affordability
# 391          AAN1        H#              1300            0.5             1

# %%
## Export dataframe to csv
data_dir = base + r"/data/raw"
fp_output_file = data_dir + r"/apartments2_391.csv"

apartments2_df.to_csv(fp_output_file)

# apartments2_df.to_csv('apartments2_391.csv')

# %% [markdown]
# Additional batch API calls were performed to obtain the remaining rental estimates in rows 392 to 555 of `apatments_2.csv` and the results appended to an intermediate file that was concatenated with `apartments2_391.csv` to create `apartments_final.csv` for a final total of 547 records as there were 4 apartments without an [APN](https://en.wikipedia.org/wiki/Assessor%27s_parcel_number) and another 4 for which Rentometer was unable to return a rental estimate -- i.e. due to insufficient comparable property information on which to make an estimate.

# %% [markdown]
# ## Next step: Scoring all 227,710 properties in Kent County

# %% [markdown]
# In the noteboook `rental_scoring.ipynb` we show how the rent estimates in `apartments_final` were used to generate the binary MSHDA rental affordabiltiy score (0 or 5).
