# %%
import numpy as np
import pandas as pd

# From https://towardsdatascience.com/reverse-geocoding-in-python-a915acf29eb6
# %load_ext autotime
import geopandas as gpd
import geopy
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter
import matplotlib.pyplot as plt
import plotly_express as px
import tqdm
from tqdm.notebook import tqdm_notebook

# From https://geocoder.readthedocs.io/
import geocoder

import requests
import io
import os

import datetime as dt
from datetime import date
from datetime import timedelta

from copy import deepcopy

pd.options.mode.chained_assignment = None  # default='warn'

# %% [markdown]
# ### 1. Read TaxData.csv and do some EDA

# %%
tax_data_df = pd.read_csv("TaxData.csv", low_memory=False)

# %%
tax_data_df.head()
# Out:
#          ORIGINAL APN  CENSUS TRACT COUNTY USE1 ZONING MUNICIPALITY NAME  \
# 0  30-017-02-0077-002  5.765002e+09         364   R 1B        ALLEN PARK
# 1  30-017-02-0079-002  5.765002e+09         364   R 1B        ALLEN PARK
# 2  30-017-02-0084-002  5.766001e+09         364   R 1B        ALLEN PARK
# 3  30-017-02-0086-002  5.766001e+09         364   R 1B        ALLEN PARK
# 4  30-017-02-0088-002  5.766001e+09         364   R 1B        ALLEN PARK
#
#   MUNICIPALITY CODE  PROPERTY LEVEL LATITUDE  PROPERTY LEVEL LONGITUDE  ACRES  \
# 0                30                42.243229                -83.205078  0.116
# 1                30                42.243231                -83.204885  0.117
# 2                30                42.242630                -83.204984  0.116
# 3                30                42.242630                -83.205097  0.116
# 4                30                42.242631                -83.205245  0.116
#
#    YEAR BUILT  LIVING SQUARE FEET  NUMBER OF UNITS
# 0      1950.0              1031.0              1.0
# 1      1950.0              1356.0              1.0
# 2      1950.0              1031.0              1.0
# 3      1950.0              1031.0              1.0
# 4      1950.0              1031.0              1.0

# %%
tax_data_df.describe()
# Out:
#        CENSUS TRACT  PROPERTY LEVEL LATITUDE  PROPERTY LEVEL LONGITUDE  \
# count  4.993588e+06             4.998132e+06              4.998132e+06
# mean   3.008229e+09             4.310223e+01             -8.436333e+01
# std    3.396698e+09             1.103893e+00              1.318532e+00
# min    1.000000e+02             2.905371e+01             -9.713022e+01
# 25%    5.100204e+07             4.238418e+01             -8.543257e+01
# 50%    1.578003e+09             4.268700e+01             -8.394964e+01
# 75%    5.515001e+09             4.343342e+01             -8.325475e+01
# max    9.859001e+09             4.747659e+01             -8.241986e+01
#
#               ACRES    YEAR BUILT  LIVING SQUARE FEET  NUMBER OF UNITS
# count  4.530966e+06  1.991960e+06        1.982485e+06     2.167832e+06
# mean   2.409751e+01  1.959695e+03        1.696460e+03     1.027096e+00
# std    5.048321e+03  2.857208e+01        4.409584e+03     3.778352e-01
# min    1.000000e-04  1.700000e+03        1.000000e+00     1.000000e+00
# 25%    1.650000e-01  1.942000e+03        1.064000e+03     1.000000e+00
# 50%    3.630000e-01  1.958000e+03        1.440000e+03     1.000000e+00
# 75%    2.000000e+00  1.980000e+03        1.998000e+03     1.000000e+00
# max    3.102156e+06  2.016000e+03        4.622108e+06     9.100000e+01

# %%
tax_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5070108 entries, 0 to 5070107
# Data columns (total 12 columns):
#  #   Column                    Dtype
# ---  ------                    -----
#  0   ORIGINAL APN              object
#  1   CENSUS TRACT              float64
#  2   COUNTY USE1               object
#  3   ZONING                    object
#  4   MUNICIPALITY NAME         object
#  5   MUNICIPALITY CODE         object
#  6   PROPERTY LEVEL LATITUDE   float64
#  7   PROPERTY LEVEL LONGITUDE  float64
#  8   ACRES                     float64
#  9   YEAR BUILT                float64
#  10  LIVING SQUARE FEET        float64
#  11  NUMBER OF UNITS           float64
# dtypes: float64(7), object(5)
# memory usage: 464.2+ MB

# %%
tax_data_df = tax_data_df.rename(columns={"PROPERTY LEVEL LATITUDE": "LAT", 
                                          "PROPERTY LEVEL LONGITUDE": "LNG"})
tax_data_df["AGE"] = dt.date.today().year - tax_data_df["YEAR BUILT"].iloc[0]
tax_data_df["PLACE NAME"] = ""
tax_data_df["ZIP CODE"] = ""

# %%
tax_data_df = tax_data_df[tax_data_df["LAT"].notnull()]

# %%
tax_data_df.isnull().sum()
# Out:
# ORIGINAL APN                0
# CENSUS TRACT            47243
# COUNTY USE1                 0
# ZONING                3791388
# MUNICIPALITY NAME           2
# MUNICIPALITY CODE           2
# LAT                         0
# LNG                         0
# ACRES                  518616
# YEAR BUILT            3006384
# LIVING SQUARE FEET    3015723
# NUMBER OF UNITS       2831891
# AGE                         0
# PLACE NAME                  0
# ZIP CODE                    0
# dtype: int64

# %%
tax_data_df.head()
# Out:
#          ORIGINAL APN  CENSUS TRACT COUNTY USE1 ZONING MUNICIPALITY NAME  \
# 0  30-017-02-0077-002  5.765002e+09         364   R 1B        ALLEN PARK
# 1  30-017-02-0079-002  5.765002e+09         364   R 1B        ALLEN PARK
# 2  30-017-02-0084-002  5.766001e+09         364   R 1B        ALLEN PARK
# 3  30-017-02-0086-002  5.766001e+09         364   R 1B        ALLEN PARK
# 4  30-017-02-0088-002  5.766001e+09         364   R 1B        ALLEN PARK
#
#   MUNICIPALITY CODE        LAT        LNG  ACRES  YEAR BUILT  \
# 0                30  42.243229 -83.205078  0.116      1950.0
# 1                30  42.243231 -83.204885  0.117      1950.0
# 2                30  42.242630 -83.204984  0.116      1950.0
# 3                30  42.242630 -83.205097  0.116      1950.0
# 4                30  42.242631 -83.205245  0.116      1950.0
#
#    LIVING SQUARE FEET  NUMBER OF UNITS   AGE PLACE NAME ZIP CODE
# 0              1031.0              1.0  70.0
# 1              1356.0              1.0  70.0
# 2              1031.0              1.0  70.0
# 3              1031.0              1.0  70.0
# 4              1031.0              1.0  70.0

# %%
len(tax_data_df)
# Out:
# 4998132

# %% [markdown]
# ### 1.1 Sample lat/lng coordinates to test reverse geocoding

# %%
# Lat and lng of Googleplex
lat1 = "37.419857"
lng1 = "-122.078827"

# %%
# Lat and lng of first entry in tax_data_df
lat2 = "42.243229"
lng2 = "-83.205078"

# %% [markdown]
# ## 2. Subset tax_data_df to test geocoding

# %%
# Data set is too large to perform API call in a single for loop
tax_data_df_1 = tax_data_df.iloc[0:10]
tax_data_df_1
# Out:
#          ORIGINAL APN  CENSUS TRACT COUNTY USE1 ZONING MUNICIPALITY NAME  \
# 0  30-017-02-0077-002  5.765002e+09         364   R 1B        ALLEN PARK
# 1  30-017-02-0079-002  5.765002e+09         364   R 1B        ALLEN PARK
# 2  30-017-02-0084-002  5.766001e+09         364   R 1B        ALLEN PARK
# 3  30-017-02-0086-002  5.766001e+09         364   R 1B        ALLEN PARK
# 4  30-017-02-0088-002  5.766001e+09         364   R 1B        ALLEN PARK
# 5  30-017-02-0090-002  5.766001e+09         364   R 1B        ALLEN PARK
# 6  30-017-02-0093-000  5.766001e+09         364   R 1B        ALLEN PARK
# 7  30-017-02-0095-000  5.766001e+09         364   R 1B        ALLEN PARK
# 8  30-017-02-0097-000  5.766001e+09         364   R 1B        ALLEN PARK
# 9  30-017-02-0101-002  5.766001e+09         364   R 1B        ALLEN PARK
#
#   MUNICIPALITY CODE        LAT        LNG  ACRES  YEAR BUILT  \
# 0                30  42.243229 -83.205078  0.116      1950.0
# 1                30  42.243231 -83.204885  0.117      1950.0
# 2                30  42.242630 -83.204984  0.116      1950.0
# 3                30  42.242630 -83.205097  0.116      1950.0
# 4                30  42.242631 -83.205245  0.116      1950.0
# 5                30  42.242628 -83.205442  0.114      1950.0
# 6                30  42.242626 -83.205950  0.114      1956.0
# 7                30  42.242624 -83.206113  0.101      1951.0
# 8                30  42.242624 -83.206268  0.101      1956.0
# 9                30  42.242623 -83.206635  0.139      1956.0
#
#    LIVING SQUARE FEET  NUMBER OF UNITS   AGE  \
# 0              1031.0              1.0  70.0
# 1              1356.0              1.0  70.0
# 2              1031.0              1.0  70.0
# 3              1031.0              1.0  70.0
# 4              1031.0              1.0  70.0
# 5              1443.0              1.0  70.0
# 6              1570.0              1.0  70.0
# 7              1031.0              1.0  70.0
# 8              1047.0              1.0  70.0
# 9              1052.0              1.0  70.0
#
#                                           PLACE NAME ZIP CODE
# 0  Wick Road, Allen Park, Wayne County, Michigan,...    48101
# 1  Vine Avenue, Allen Park, Wayne County, Michiga...    48101
# 2  Wick Road, Allen Park, Wayne County, Michigan,...    48101
# 3  Wick Road, Allen Park, Wayne County, Michigan,...    48101
# 4  Wick Road, Allen Park, Wayne County, Michigan,...    48101
# 5  Wick Road, Allen Park, Wayne County, Michigan,...    48101
# 6  Rosedale Boulevard, Allen Park, Wayne County, ...    48101
# 7  Wick Road, Allen Park, Wayne County, Michigan,...    48101
# 8  Wick Road, Allen Park, Wayne County, Michigan,...    48101
# 9  Hubert Avenue, Allen Park, Wayne County, Michi...    48101

# %% [markdown]
# To reverse geocode the entire dataset (4998132 rows with non-null lat/lon), we can employ MapReduce or simply break into chunks and then concatenate the results

# %% [markdown]
# ## 3. Reverse geocoding using free Openstreetmap geocoding service

# %% [markdown]
# ### 3.1 Inspect API call result using sample lat/lng

# %%
# Googleplex
coordinates = lat1, lng1
locator = Nominatim(user_agent="myGeocoder")
location = locator.reverse(coordinates)
result = location.raw
result
# Out:
# {'place_id': 118936921,
#  'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#  'osm_type': 'way',
#  'osm_id': 125372590,
#  'lat': '37.41984925',
#  'lon': '-122.07885167838052',
#  'display_name': 'Google 1842, 1842, North Shoreline Boulevard, Mountain View, Santa Clara County, California, 94043, United States',
#  'address': {'office': 'Google 1842',
#   'house_number': '1842',
#   'road': 'North Shoreline Boulevard',
#   'city': 'Mountain View',
#   'county': 'Santa Clara County',
#   'state': 'California',
#   'postcode': '94043',
#   'country': 'United States',
#   'country_code': 'us'},
#  'boundingbox': ['37.4195758', '37.4201344', '-122.0791846', '-122.0785385']}

# %%
# First entry in tax_data_df
coordinates = lat2, lng2
locator = Nominatim(user_agent="myGeocoder")
location = locator.reverse(coordinates)
result = location.raw
result
# Out:
# {'place_id': 85975463,
#  'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#  'osm_type': 'way',
#  'osm_id': 8771706,
#  'lat': '42.24299907114748',
#  'lon': '-83.20507697983786',
#  'display_name': 'Wick Road, Allen Park, Wayne County, Michigan, 48101, United States',
#  'address': {'road': 'Wick Road',
#   'town': 'Allen Park',
#   'county': 'Wayne County',
#   'state': 'Michigan',
#   'postcode': '48101',
#   'country': 'United States',
#   'country_code': 'us'},
#  'boundingbox': ['42.242862', '42.243001', '-83.208981', '-83.204641']}

# %% [markdown]
# ### 3.1 Create function to make Openstreetma API calls

# %%
def rev_geocoder_osm(df):
    
    for i in range(len(df)):
        lat = df.iloc[i]["LAT"]
        lng = df.iloc[i]["LNG"]
        coordinates = lat, lng
        
        locator = Nominatim(user_agent="myGeocoder")
        location = locator.reverse(coordinates)
        result = location.raw
        
        df["PLACE NAME"].iloc[i] = result["display_name"]
        df["ZIP CODE"].iloc[i] = result["address"]["postcode"]
        
    return df

# %%
df_osm = rev_geocoder_osm(tax_data_df_1)

# %%
df_osm
# Out:
#          ORIGINAL APN  CENSUS TRACT COUNTY USE1 ZONING MUNICIPALITY NAME  \
# 0  30-017-02-0077-002  5.765002e+09         364   R 1B        ALLEN PARK
# 1  30-017-02-0079-002  5.765002e+09         364   R 1B        ALLEN PARK
# 2  30-017-02-0084-002  5.766001e+09         364   R 1B        ALLEN PARK
# 3  30-017-02-0086-002  5.766001e+09         364   R 1B        ALLEN PARK
# 4  30-017-02-0088-002  5.766001e+09         364   R 1B        ALLEN PARK
# 5  30-017-02-0090-002  5.766001e+09         364   R 1B        ALLEN PARK
# 6  30-017-02-0093-000  5.766001e+09         364   R 1B        ALLEN PARK
# 7  30-017-02-0095-000  5.766001e+09         364   R 1B        ALLEN PARK
# 8  30-017-02-0097-000  5.766001e+09         364   R 1B        ALLEN PARK
# 9  30-017-02-0101-002  5.766001e+09         364   R 1B        ALLEN PARK
#
#   MUNICIPALITY CODE        LAT        LNG  ACRES  YEAR BUILT  \
# 0                30  42.243229 -83.205078  0.116      1950.0
# 1                30  42.243231 -83.204885  0.117      1950.0
# 2                30  42.242630 -83.204984  0.116      1950.0
# 3                30  42.242630 -83.205097  0.116      1950.0
# 4                30  42.242631 -83.205245  0.116      1950.0
# 5                30  42.242628 -83.205442  0.114      1950.0
# 6                30  42.242626 -83.205950  0.114      1956.0
# 7                30  42.242624 -83.206113  0.101      1951.0
# 8                30  42.242624 -83.206268  0.101      1956.0
# 9                30  42.242623 -83.206635  0.139      1956.0
#
#    LIVING SQUARE FEET  NUMBER OF UNITS   AGE  \
# 0              1031.0              1.0  70.0
# 1              1356.0              1.0  70.0
# 2              1031.0              1.0  70.0
# 3              1031.0              1.0  70.0
# 4              1031.0              1.0  70.0
# 5              1443.0              1.0  70.0
# 6              1570.0              1.0  70.0
# 7              1031.0              1.0  70.0
# 8              1047.0              1.0  70.0
# 9              1052.0              1.0  70.0
#
#                                           PLACE NAME ZIP CODE
# 0  Wick Road, Allen Park, Wayne County, Michigan,...    48101
# 1  Vine Avenue, Allen Park, Wayne County, Michiga...    48101
# 2  Wick Road, Allen Park, Wayne County, Michigan,...    48101
# 3  Wick Road, Allen Park, Wayne County, Michigan,...    48101
# 4  Wick Road, Allen Park, Wayne County, Michigan,...    48101
# 5  Wick Road, Allen Park, Wayne County, Michigan,...    48101
# 6  Rosedale Boulevard, Allen Park, Wayne County, ...    48101
# 7  Wick Road, Allen Park, Wayne County, Michigan,...    48101
# 8  Wick Road, Allen Park, Wayne County, Michigan,...    48101
# 9  Hubert Avenue, Allen Park, Wayne County, Michi...    48101

# %% [markdown]
# ## 4. Reverse geocoding using Google Geocoding API

# %% [markdown]
# ### 4.1 Inspect API call result using sample lat/lng
# Note: This returns a very long dict

# %%
# Googleplex
lat = lat1
lng = lng1

# Set URL string
url = "https://maps.googleapis.com/maps/api/geocode/json?latlng="+lat+","+lng+"&key="+key

response = requests.get(url)
result = response.json()
result
# Out:
# {'plus_code': {'compound_code': 'CW9C+WF Mountain View, CA, USA',
#   'global_code': '849VCW9C+WF'},
#  'results': [{'address_components': [{'long_name': '1842',
#      'short_name': '1842',
#      'types': ['street_number']},
#     {'long_name': 'North Shoreline Boulevard',
#      'short_name': 'N Shoreline Blvd',
#      'types': ['route']},
#     {'long_name': 'Mountain View',
#      'short_name': 'Mountain View',
#      'types': ['locality', 'political']},
#     {'long_name': 'Santa Clara County',
#      'short_name': 'Santa Clara County',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'California',
#      'short_name': 'CA',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'United States',
#      'short_name': 'US',
#      'types': ['country', 'political']},
#     {'long_name': '94043', 'short_name': '94043', 'types': ['postal_code']}],
#    'formatted_address': '1842 N Shoreline Blvd, Mountain View, CA 94043, USA',
#    'geometry': {'location': {'lat': 37.419851, 'lng': -122.0788177},
#     'location_type': 'ROOFTOP',
#     'viewport': {'northeast': {'lat': 37.4211999802915,
#       'lng': -122.0774687197085},
#      'southwest': {'lat': 37.41850201970851, 'lng': -122.0801666802915}}},
#    'place_id': 'ChIJ1-9GB_-5j4AR3Ioxan-DqBQ',
#    'plus_code': {'compound_code': 'CW9C+WF Mountain View, CA, USA',
#     'global_code': '849VCW9C+WF'},
#    'types': ['establishment', 'point_of_interest']},
#   {'address_components': [{'long_name': '1455',
#      'short_name': '1455',
#      'types': ['street_number']},
#     {'long_name': 'Charleston Road',
#      'short_name': 'Charleston Rd',
#      'types': ['route']},
#     {'long_name': 'Mountain View',
#      'short_name': 'Mountain View',
#      'types': ['locality', 'political']},
#     {'long_name': 'Santa Clara County',
#      'short_name': 'Santa Clara County',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'California',
#      'short_name': 'CA',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'United States',
#      'short_name': 'US',
#      'types': ['country', 'political']},
#     {'long_name': '94043', 'short_name': '94043', 'types': ['postal_code']}],
#    'formatted_address': '1455 Charleston Rd, Mountain View, CA 94043, USA',
#    'geometry': {'location': {'lat': 37.4198937, 'lng': -122.0789121},
#     'location_type': 'ROOFTOP',
#     'viewport': {'northeast': {'lat': 37.42124268029149,
#       'lng': -122.0775631197085},
#      'southwest': {'lat': 37.41854471970849, 'lng': -122.0802610802915}}},
#    'place_id': 'ChIJ4cEvkP65j4ARdLNW1d-Ulo8',
#    'plus_code': {'compound_code': 'CW9C+XC Mountain View, CA, USA',
#     'global_code': '849VCW9C+XC'},
#    'types': ['street_address']},
#   {'address_components': [{'long_name': 'US-MTV-1842',
#      'short_name': 'US-MTV-1842',
#      'types': ['premise']},
#     {'long_name': '1842', 'short_name': '1842', 'types': ['street_number']},
#     {'long_name': 'North Shoreline Boulevard',
#      'short_name': 'N Shoreline Blvd',
#      'types': ['route']},
#     {'long_name': 'Mountain View',
#      'short_name': 'Mountain View',
#      'types': ['locality', 'political']},
#     {'long_name': 'Santa Clara County',
#      'short_name': 'Santa Clara County',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'California',
#      'short_name': 'CA',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'United States',
#      'short_name': 'US',
#      'types': ['country', 'political']},
#     {'long_name': '94043', 'short_name': '94043', 'types': ['postal_code']}],
#    'formatted_address': 'US-MTV-1842, 1842 N Shoreline Blvd, Mountain View, CA 94043, USA',
#    'geometry': {'bounds': {'northeast': {'lat': 37.4200841,
#       'lng': -122.0785352},
#      'southwest': {'lat': 37.4196325, 'lng': -122.0791188}},
#     'location': {'lat': 37.419851, 'lng': -122.0788177},
#     'location_type': 'ROOFTOP',
#     'viewport': {'northeast': {'lat': 37.4212072802915,
#       'lng': -122.0774780197085},
#      'southwest': {'lat': 37.4185093197085, 'lng': -122.0801759802915}}},
#    'place_id': 'ChIJKesZhf65j4ARxoBh866SiDM',
#    'types': ['premise']},
#   {'address_components': [{'long_name': 'Unnamed Road',
#      'short_name': 'Unnamed Road',
#      'types': ['route']},
#     {'long_name': 'Mountain View',
#      'short_name': 'Mountain View',
#      'types': ['locality', 'political']},
#     {'long_name': 'Santa Clara County',
#      'short_name': 'Santa Clara County',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'California',
#      'short_name': 'CA',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'United States',
#      'short_name': 'US',
#      'types': ['country', 'political']},
#     {'long_name': '94043', 'short_name': '94043', 'types': ['postal_code']}],
#    'formatted_address': 'Unnamed Road, Mountain View, CA 94043, USA',
#    'geometry': {'bounds': {'northeast': {'lat': 37.4201795,
#       'lng': -122.0787677},
#      'southwest': {'lat': 37.4201578, 'lng': -122.0791096}},
#     'location': {'lat': 37.4201687, 'lng': -122.0789386},
#     'location_type': 'GEOMETRIC_CENTER',
#     'viewport': {'northeast': {'lat': 37.4215176302915,
#       'lng': -122.0775896697085},
#      'southwest': {'lat': 37.4188196697085, 'lng': -122.0802876302915}}},
#    'place_id': 'ChIJYSamkP65j4ARuu8Ba9OBlOE',
#    'types': ['route']},
#   {'address_components': [{'long_name': '94043',
#      'short_name': '94043',
#      'types': ['postal_code']},
#     {'long_name': 'Mountain View',
#      'short_name': 'Mountain View',
#      'types': ['locality', 'political']},
#     {'long_name': 'Santa Clara County',
#      'short_name': 'Santa Clara County',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'California',
#      'short_name': 'CA',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'United States',
#      'short_name': 'US',
#      'types': ['country', 'political']}],
#    'formatted_address': 'Mountain View, CA 94043, USA',
#    'geometry': {'bounds': {'northeast': {'lat': 37.45209210000001,
#       'lng': -122.0359899},
#      'southwest': {'lat': 37.3857439, 'lng': -122.10842}},
#     'location': {'lat': 37.4062237, 'lng': -122.0781663},
#     'location_type': 'APPROXIMATE',
#     'viewport': {'northeast': {'lat': 37.45209210000001, 'lng': -122.0359899},
#      'southwest': {'lat': 37.3857439, 'lng': -122.10842}}},
#    'place_id': 'ChIJoQmen1G3j4ARbhoe7nVBEoQ',
#    'types': ['postal_code']},
#   {'address_components': [{'long_name': 'Mountain View',
#      'short_name': 'Mountain View',
#      'types': ['locality', 'political']},
#     {'long_name': 'Santa Clara County',
#      'short_name': 'Santa Clara County',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'California',
#      'short_name': 'CA',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'United States',
#      'short_name': 'US',
#      'types': ['country', 'political']}],
#    'formatted_address': 'Mountain View, CA, USA',
#    'geometry': {'bounds': {'northeast': {'lat': 37.469887,
#       'lng': -122.0446721},
#      'southwest': {'lat': 37.3567832, 'lng': -122.1178619}},
#     'location': {'lat': 37.3860517, 'lng': -122.0838511},
#     'location_type': 'APPROXIMATE',
#     'viewport': {'northeast': {'lat': 37.469887, 'lng': -122.0446721},
#      'southwest': {'lat': 37.3567832, 'lng': -122.1178619}}},
#    'place_id': 'ChIJiQHsW0m3j4ARm69rRkrUF3w',
#    'types': ['locality', 'political']},
#   {'address_components': [{'long_name': 'San Francisco Peninsula',
#      'short_name': 'San Francisco Peninsula',
#      'types': ['establishment', 'natural_feature']},
#     {'long_name': 'California',
#      'short_name': 'CA',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'United States',
#      'short_name': 'US',
#      'types': ['country', 'political']}],
#    'formatted_address': 'San Francisco Peninsula, California, USA',
#    'geometry': {'bounds': {'northeast': {'lat': 37.811608,
#       'lng': -121.9835243},
#      'southwest': {'lat': 37.2295212, 'lng': -122.5251532}},
#     'location': {'lat': 37.4614629, 'lng': -122.3107517},
#     'location_type': 'APPROXIMATE',
#     'viewport': {'northeast': {'lat': 37.811608, 'lng': -121.9835243},
#      'southwest': {'lat': 37.2295212, 'lng': -122.5251532}}},
#    'place_id': 'ChIJYyep9FV2j4ARqfLae7BmREU',
#    'types': ['establishment', 'natural_feature']},
#   {'address_components': [{'long_name': 'Santa Clara County',
#      'short_name': 'Santa Clara County',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'California',
#      'short_name': 'CA',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'United States',
#      'short_name': 'US',
#      'types': ['country', 'political']}],
#    'formatted_address': 'Santa Clara County, CA, USA',
#    'geometry': {'bounds': {'northeast': {'lat': 37.484637, 'lng': -121.208178},
#      'southwest': {'lat': 36.8941549, 'lng': -122.202476}},
#     'location': {'lat': 37.3336581, 'lng': -121.8907041},
#     'location_type': 'APPROXIMATE',
#     'viewport': {'northeast': {'lat': 37.484637, 'lng': -121.208178},
#      'southwest': {'lat': 36.8941549, 'lng': -122.202476}}},
#    'place_id': 'ChIJd_Y0eVIvkIARuQyDN0F1LBA',
#    'types': ['administrative_area_level_2', 'political']},
#   {'address_components': [{'long_name': 'California',
#      'short_name': 'CA',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'United States',
#      'short_name': 'US',
#      'types': ['country', 'political']}],
#    'formatted_address': 'California, USA',
#    'geometry': {'bounds': {'northeast': {'lat': 42.0095169,
#       'lng': -114.131211},
#      'southwest': {'lat': 32.528832, 'lng': -124.482003}},
#     'location': {'lat': 36.778261, 'lng': -119.4179324},
#     'location_type': 'APPROXIMATE',
#     'viewport': {'northeast': {'lat': 42.0095169, 'lng': -114.131211},
#      'southwest': {'lat': 32.528832, 'lng': -124.482003}}},
#    'place_id': 'ChIJPV4oX_65j4ARVW8IJ6IJUYs',
#    'types': ['administrative_area_level_1', 'political']},
#   {'address_components': [{'long_name': 'United States',
#      'short_name': 'US',
#      'types': ['country', 'political']}],
#    'formatted_address': 'United States',
#    'geometry': {'bounds': {'northeast': {'lat': 71.5388001, 'lng': -66.885417},
#      'southwest': {'lat': 18.7763, 'lng': 170.5957}},
#     'location': {'lat': 37.09024, 'lng': -95.712891},
#     'location_type': 'APPROXIMATE',
#     'viewport': {'northeast': {'lat': 71.5388001, 'lng': -66.885417},
#      'southwest': {'lat': 18.7763, 'lng': 170.5957}}},
#    'place_id': 'ChIJCzYy5IS16lQRQrfeQ5K5Oxw',
#    'types': ['country', 'political']},
#   {'address_components': [{'long_name': 'CW9C+WF',
#      'short_name': 'CW9C+WF',
#      'types': ['plus_code']},
#     {'long_name': 'Mountain View',
#      'short_name': 'Mountain View',
#      'types': ['locality', 'political']},
#     {'long_name': 'Santa Clara County',
#      'short_name': 'Santa Clara County',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'California',
#      'short_name': 'CA',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'United States',
#      'short_name': 'US',
#      'types': ['country', 'political']}],
#    'formatted_address': 'CW9C+WF Mountain View, CA, USA',
#    'geometry': {'bounds': {'northeast': {'lat': 37.419875, 'lng': -122.07875},
#      'southwest': {'lat': 37.41975, 'lng': -122.078875}},
#     'location': {'lat': 37.419857, 'lng': -122.078827},
#     'location_type': 'ROOFTOP',
#     'viewport': {'northeast': {'lat': 37.4211614802915,
#       'lng': -122.0774635197085},
#      'southwest': {'lat': 37.4184635197085, 'lng': -122.0801614802915}}},
#    'place_id': 'GhIJk__J3721QkARq8JmgAuFXsA',
#    'plus_code': {'compound_code': 'CW9C+WF Mountain View, CA, USA',
#     'global_code': '849VCW9C+WF'},
#    'types': ['plus_code']}],
#  'status': 'OK'}

# %%
# First entry in tax_data_df 
lat = lat2 
lng = lng2

# Set URL string
url = "https://maps.googleapis.com/maps/api/geocode/json?latlng="+lat+","+lng+"&key="+key

response = requests.get(url)
result = response.json()
result
# Out:
# {'plus_code': {'compound_code': '6QVV+7X Allen Park, MI, USA',
#   'global_code': '86JR6QVV+7X'},
#  'results': [{'address_components': [{'long_name': '4714',
#      'short_name': '4714',
#      'types': ['street_number']},
#     {'long_name': 'Wick Road', 'short_name': 'Wick Rd', 'types': ['route']},
#     {'long_name': 'Allen Park',
#      'short_name': 'Allen Park',
#      'types': ['locality', 'political']},
#     {'long_name': 'Wayne County',
#      'short_name': 'Wayne County',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Michigan',
#      'short_name': 'MI',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'United States',
#      'short_name': 'US',
#      'types': ['country', 'political']},
#     {'long_name': '48101', 'short_name': '48101', 'types': ['postal_code']}],
#    'formatted_address': '4714 Wick Rd, Allen Park, MI 48101, USA',
#    'geometry': {'bounds': {'northeast': {'lat': 42.2432658,
#       'lng': -83.2049682},
#      'southwest': {'lat': 42.2431537, 'lng': -83.2050752}},
#     'location': {'lat': 42.2432065, 'lng': -83.20502359999999},
#     'location_type': 'ROOFTOP',
#     'viewport': {'northeast': {'lat': 42.2445587302915,
#       'lng': -83.2036727197085},
#      'southwest': {'lat': 42.2418607697085, 'lng': -83.20637068029151}}},
#    'place_id': 'ChIJp3GlCvc2O4gR9EYLIkPYTlo',
#    'types': ['premise']},
#   {'address_components': [{'long_name': '14714',
#      'short_name': '14714',
#      'types': ['street_number']},
#     {'long_name': 'Wick Road', 'short_name': 'Wick Rd', 'types': ['route']},
#     {'long_name': 'Allen Park',
#      'short_name': 'Allen Park',
#      'types': ['locality', 'political']},
#     {'long_name': 'Wayne County',
#      'short_name': 'Wayne County',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Michigan',
#      'short_name': 'MI',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'United States',
#      'short_name': 'US',
#      'types': ['country', 'political']},
#     {'long_name': '48101', 'short_name': '48101', 'types': ['postal_code']},
#     {'long_name': '1640',
#      'short_name': '1640',
#      'types': ['postal_code_suffix']}],
#    'formatted_address': '14714 Wick Rd, Allen Park, MI 48101, USA',
#    'geometry': {'location': {'lat': 42.2432279, 'lng': -83.2049834},
#     'location_type': 'ROOFTOP',
#     'viewport': {'northeast': {'lat': 42.2445768802915,
#       'lng': -83.2036344197085},
#      'southwest': {'lat': 42.2418789197085, 'lng': -83.20633238029151}}},
#    'place_id': 'ChIJlRjqCvc2O4gRlvo6ku7ZTKc',
#    'plus_code': {'compound_code': '6QVW+72 Allen Park, MI, USA',
#     'global_code': '86JR6QVW+72'},
#    'types': ['street_address']},
#   {'address_components': [{'long_name': '9249',
#      'short_name': '9249',
#      'types': ['street_number']},
#     {'long_name': 'Vine Avenue', 'short_name': 'Vine Ave', 'types': ['route']},
#     {'long_name': 'Allen Park',
#      'short_name': 'Allen Park',
#      'types': ['locality', 'political']},
#     {'long_name': 'Wayne County',
#      'short_name': 'Wayne County',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Michigan',
#      'short_name': 'MI',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'United States',
#      'short_name': 'US',
#      'types': ['country', 'political']},
#     {'long_name': '48101', 'short_name': '48101', 'types': ['postal_code']},
#     {'long_name': '1651',
#      'short_name': '1651',
#      'types': ['postal_code_suffix']}],
#    'formatted_address': '9249 Vine Ave, Allen Park, MI 48101, USA',
#    'geometry': {'location': {'lat': 42.24301579999999, 'lng': -83.2045205},
#     'location_type': 'ROOFTOP',
#     'viewport': {'northeast': {'lat': 42.2443647802915,
#       'lng': -83.20317151970849},
#      'southwest': {'lat': 42.2416668197085, 'lng': -83.20586948029151}}},
#    'place_id': 'ChIJP7Iac_c2O4gRwOUM0Ma8MDY',
#    'plus_code': {'compound_code': '6QVW+65 Allen Park, MI, USA',
#     'global_code': '86JR6QVW+65'},
#    'types': ['electronics_store',
#     'establishment',
#     'home_goods_store',
#     'point_of_interest',
#     'school',
#     'store']},
#   {'address_components': [{'long_name': '4718',
#      'short_name': '4718',
#      'types': ['street_number']},
#     {'long_name': 'Wick Road', 'short_name': 'Wick Rd', 'types': ['route']},
#     {'long_name': 'Allen Park',
#      'short_name': 'Allen Park',
#      'types': ['locality', 'political']},
#     {'long_name': 'Wayne County',
#      'short_name': 'Wayne County',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Michigan',
#      'short_name': 'MI',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'United States',
#      'short_name': 'US',
#      'types': ['country', 'political']},
#     {'long_name': '48101', 'short_name': '48101', 'types': ['postal_code']}],
#    'formatted_address': '4718 Wick Rd, Allen Park, MI 48101, USA',
#    'geometry': {'location': {'lat': 42.2429979, 'lng': -83.2050879},
#     'location_type': 'RANGE_INTERPOLATED',
#     'viewport': {'northeast': {'lat': 42.24434688029149,
#       'lng': -83.20373891970848},
#      'southwest': {'lat': 42.2416489197085, 'lng': -83.2064368802915}}},
#    'place_id': 'Eic0NzE4IFdpY2sgUmQsIEFsbGVuIFBhcmssIE1JIDQ4MTAxLCBVU0EiGxIZChQKEgkx-EGe9zY7iBH1V7DXmwULfBDuJA',
#    'types': ['street_address']},
#   {'address_components': [{'long_name': 'Wick Road',
#      'short_name': 'Wick Rd',
#      'types': ['route']},
#     {'long_name': 'Allen Park',
#      'short_name': 'Allen Park',
#      'types': ['locality', 'political']},
#     {'long_name': 'Wayne County',
#      'short_name': 'Wayne County',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Michigan',
#      'short_name': 'MI',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'United States',
#      'short_name': 'US',
#      'types': ['country', 'political']},
#     {'long_name': '48101', 'short_name': '48101', 'types': ['postal_code']}],
#    'formatted_address': 'Wick Rd, Allen Park, MI 48101, USA',
#    'geometry': {'bounds': {'northeast': {'lat': 42.243001, 'lng': -83.204641},
#      'southwest': {'lat': 42.2429935, 'lng': -83.205739}},
#     'location': {'lat': 42.2429973, 'lng': -83.20519},
#     'location_type': 'GEOMETRIC_CENTER',
#     'viewport': {'northeast': {'lat': 42.2443462302915,
#       'lng': -83.20384101970849},
#      'southwest': {'lat': 42.2416482697085, 'lng': -83.20653898029151}}},
#    'place_id': 'ChIJMfhBnvc2O4gR9Few15sFC3w',
#    'types': ['route']},
#   {'address_components': [{'long_name': '48101',
#      'short_name': '48101',
#      'types': ['postal_code']},
#     {'long_name': 'Allen Park',
#      'short_name': 'Allen Park',
#      'types': ['locality', 'political']},
#     {'long_name': 'Wayne County',
#      'short_name': 'Wayne County',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Michigan',
#      'short_name': 'MI',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'United States',
#      'short_name': 'US',
#      'types': ['country', 'political']}],
#    'formatted_address': 'Allen Park, MI 48101, USA',
#    'geometry': {'bounds': {'northeast': {'lat': 42.300989, 'lng': -83.18364},
#      'southwest': {'lat': 42.222783, 'lng': -83.231911}},
#     'location': {'lat': 42.2427186, 'lng': -83.2184763},
#     'location_type': 'APPROXIMATE',
#     'viewport': {'northeast': {'lat': 42.300989, 'lng': -83.18364},
#      'southwest': {'lat': 42.222783, 'lng': -83.231911}}},
#    'place_id': 'ChIJdxkds2I2O4gRA5oYxGqnQ7M',
#    'types': ['postal_code']},
#   {'address_components': [{'long_name': 'Allen Park',
#      'short_name': 'Allen Park',
#      'types': ['locality', 'political']},
#     {'long_name': 'Wayne County',
#      'short_name': 'Wayne County',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Michigan',
#      'short_name': 'MI',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'United States',
#      'short_name': 'US',
#      'types': ['country', 'political']},
#     {'long_name': '48101', 'short_name': '48101', 'types': ['postal_code']}],
#    'formatted_address': 'Allen Park, MI 48101, USA',
#    'geometry': {'bounds': {'northeast': {'lat': 42.300989, 'lng': -83.18364},
#      'southwest': {'lat': 42.222783, 'lng': -83.231911}},
#     'location': {'lat': 42.2575385, 'lng': -83.2110375},
#     'location_type': 'APPROXIMATE',
#     'viewport': {'northeast': {'lat': 42.300989, 'lng': -83.18364},
#      'southwest': {'lat': 42.222783, 'lng': -83.231911}}},
#    'place_id': 'ChIJm5Yp_mI2O4gRPR_-Q5531ps',
#    'types': ['locality', 'political']},
#   {'address_components': [{'long_name': 'Wayne County',
#      'short_name': 'Wayne County',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Michigan',
#      'short_name': 'MI',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'United States',
#      'short_name': 'US',
#      'types': ['country', 'political']}],
#    'formatted_address': 'Wayne County, MI, USA',
#    'geometry': {'bounds': {'northeast': {'lat': 42.451557, 'lng': -82.7499078},
#      'southwest': {'lat': 42.02793, 'lng': -83.55190689999999}},
#     'location': {'lat': 42.2790746, 'lng': -83.33618799999999},
#     'location_type': 'APPROXIMATE',
#     'viewport': {'northeast': {'lat': 42.451557, 'lng': -82.7499078},
#      'southwest': {'lat': 42.02793, 'lng': -83.55190689999999}}},
#    'place_id': 'ChIJDZ6VuYPKJIgR15xhPzwyGyw',
#    'types': ['administrative_area_level_2', 'political']},
#   {'address_components': [{'long_name': 'Michigan',
#      'short_name': 'MI',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'United States',
#      'short_name': 'US',
#      'types': ['country', 'political']}],
#    'formatted_address': 'Michigan, USA',
#    'geometry': {'bounds': {'northeast': {'lat': 48.3056044,
#       'lng': -82.1229766},
#      'southwest': {'lat': 41.696118, 'lng': -90.4181358}},
#     'location': {'lat': 44.3148443, 'lng': -85.60236429999999},
#     'location_type': 'APPROXIMATE',
#     'viewport': {'northeast': {'lat': 48.3056044, 'lng': -82.1229766},
#      'southwest': {'lat': 41.696118, 'lng': -90.4181358}}},
#    'place_id': 'ChIJEQTKxz2qTE0Rs8liellI3Zc',
#    'types': ['administrative_area_level_1', 'political']},
#   {'address_components': [{'long_name': 'United States',
#      'short_name': 'US',
#      'types': ['country', 'political']}],
#    'formatted_address': 'United States',
#    'geometry': {'bounds': {'northeast': {'lat': 71.5388001, 'lng': -66.885417},
#      'southwest': {'lat': 18.7763, 'lng': 170.5957}},
#     'location': {'lat': 37.09024, 'lng': -95.712891},
#     'location_type': 'APPROXIMATE',
#     'viewport': {'northeast': {'lat': 71.5388001, 'lng': -66.885417},
#      'southwest': {'lat': 18.7763, 'lng': 170.5957}}},
#    'place_id': 'ChIJCzYy5IS16lQRQrfeQ5K5Oxw',
#    'types': ['country', 'political']},
#   {'address_components': [{'long_name': '6QVV+7X',
#      'short_name': '6QVV+7X',
#      'types': ['plus_code']},
#     {'long_name': 'Allen Park',
#      'short_name': 'Allen Park',
#      'types': ['locality', 'political']},
#     {'long_name': 'Wayne County',
#      'short_name': 'Wayne County',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Michigan',
#      'short_name': 'MI',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'United States',
#      'short_name': 'US',
#      'types': ['country', 'political']},
#     {'long_name': '48101', 'short_name': '48101', 'types': ['postal_code']}],
#    'formatted_address': '6QVV+7X Allen Park, MI, USA',
#    'geometry': {'bounds': {'northeast': {'lat': 42.24325, 'lng': -83.205},
#      'southwest': {'lat': 42.24312500000001, 'lng': -83.205125}},
#     'location': {'lat': 42.243229, 'lng': -83.205078},
#     'location_type': 'ROOFTOP',
#     'viewport': {'northeast': {'lat': 42.2445364802915,
#       'lng': -83.20371351970849},
#      'southwest': {'lat': 42.2418385197085, 'lng': -83.20641148029151}}},
#    'place_id': 'GhIJKji8ICIfRUARQ8h5_x_NVMA',
#    'plus_code': {'compound_code': '6QVV+7X Allen Park, MI, USA',
#     'global_code': '86JR6QVV+7X'},
#    'types': ['plus_code']}],
#  'status': 'OK'}

# %% [markdown]
# ### 4.2 Explore result of API call

# %%
result.get("results")[0]
# Out:
# {'address_components': [{'long_name': '4714',
#    'short_name': '4714',
#    'types': ['street_number']},
#   {'long_name': 'Wick Road', 'short_name': 'Wick Rd', 'types': ['route']},
#   {'long_name': 'Allen Park',
#    'short_name': 'Allen Park',
#    'types': ['locality', 'political']},
#   {'long_name': 'Wayne County',
#    'short_name': 'Wayne County',
#    'types': ['administrative_area_level_2', 'political']},
#   {'long_name': 'Michigan',
#    'short_name': 'MI',
#    'types': ['administrative_area_level_1', 'political']},
#   {'long_name': 'United States',
#    'short_name': 'US',
#    'types': ['country', 'political']},
#   {'long_name': '48101', 'short_name': '48101', 'types': ['postal_code']}],
#  'formatted_address': '4714 Wick Rd, Allen Park, MI 48101, USA',
#  'geometry': {'bounds': {'northeast': {'lat': 42.2432658, 'lng': -83.2049682},
#    'southwest': {'lat': 42.2431537, 'lng': -83.2050752}},
#   'location': {'lat': 42.2432065, 'lng': -83.20502359999999},
#   'location_type': 'ROOFTOP',
#   'viewport': {'northeast': {'lat': 42.2445587302915,
#     'lng': -83.2036727197085},
#    'southwest': {'lat': 42.2418607697085, 'lng': -83.20637068029151}}},
#  'place_id': 'ChIJp3GlCvc2O4gR9EYLIkPYTlo',
#  'types': ['premise']}

# %%
# Get formatted address from result
result.get("results")[0].get("formatted_address")
# Out:
# '4714 Wick Rd, Allen Park, MI 48101, USA'

# %%
result.get("results")[0].get("address_components")
# Out:
# [{'long_name': '4714', 'short_name': '4714', 'types': ['street_number']},
#  {'long_name': 'Wick Road', 'short_name': 'Wick Rd', 'types': ['route']},
#  {'long_name': 'Allen Park',
#   'short_name': 'Allen Park',
#   'types': ['locality', 'political']},
#  {'long_name': 'Wayne County',
#   'short_name': 'Wayne County',
#   'types': ['administrative_area_level_2', 'political']},
#  {'long_name': 'Michigan',
#   'short_name': 'MI',
#   'types': ['administrative_area_level_1', 'political']},
#  {'long_name': 'United States',
#   'short_name': 'US',
#   'types': ['country', 'political']},
#  {'long_name': '48101', 'short_name': '48101', 'types': ['postal_code']}]

# %%
# Get zip code from result
result.get("results")[0].get("address_components")[6]["long_name"]
# Out:
# '48101'

# %% [markdown]
# ### 4.3 Create function to make Google Geocoding API calls

# %%
def rev_geocoder_google():

    for i in range(len(df)):
        lat = df.iloc[i]["LAT"]
        lng = df.iloc[i]["LNG"]
        
        key="AIzaSyD-NRUsF_OkkWaaz_iWootCLYlp2UR6hPw"
        url = "https://maps.googleapis.com/maps/api/geocode/json?latlng="+lat+","+lng+"&key="+key
        
        response = requests.get(url)
        result = response.json()

        df["PLACE NAME"].iloc[i] = result.get("results")[0].get("address_components")
        df["ZIP CODE"].iloc[i] = result.get("results")[0].get("address_components")[6]["long_name"]
        
    return df

# %%
df_google = rev_geocoder_osm(tax_data_df_1)

# %%
df_google
# Out:
#          ORIGINAL APN  CENSUS TRACT COUNTY USE1 ZONING MUNICIPALITY NAME  \
# 0  30-017-02-0077-002  5.765002e+09         364   R 1B        ALLEN PARK
# 1  30-017-02-0079-002  5.765002e+09         364   R 1B        ALLEN PARK
# 2  30-017-02-0084-002  5.766001e+09         364   R 1B        ALLEN PARK
# 3  30-017-02-0086-002  5.766001e+09         364   R 1B        ALLEN PARK
# 4  30-017-02-0088-002  5.766001e+09         364   R 1B        ALLEN PARK
# 5  30-017-02-0090-002  5.766001e+09         364   R 1B        ALLEN PARK
# 6  30-017-02-0093-000  5.766001e+09         364   R 1B        ALLEN PARK
# 7  30-017-02-0095-000  5.766001e+09         364   R 1B        ALLEN PARK
# 8  30-017-02-0097-000  5.766001e+09         364   R 1B        ALLEN PARK
# 9  30-017-02-0101-002  5.766001e+09         364   R 1B        ALLEN PARK
#
#   MUNICIPALITY CODE        LAT        LNG  ACRES  YEAR BUILT  \
# 0                30  42.243229 -83.205078  0.116      1950.0
# 1                30  42.243231 -83.204885  0.117      1950.0
# 2                30  42.242630 -83.204984  0.116      1950.0
# 3                30  42.242630 -83.205097  0.116      1950.0
# 4                30  42.242631 -83.205245  0.116      1950.0
# 5                30  42.242628 -83.205442  0.114      1950.0
# 6                30  42.242626 -83.205950  0.114      1956.0
# 7                30  42.242624 -83.206113  0.101      1951.0
# 8                30  42.242624 -83.206268  0.101      1956.0
# 9                30  42.242623 -83.206635  0.139      1956.0
#
#    LIVING SQUARE FEET  NUMBER OF UNITS   AGE  \
# 0              1031.0              1.0  70.0
# 1              1356.0              1.0  70.0
# 2              1031.0              1.0  70.0
# 3              1031.0              1.0  70.0
# 4              1031.0              1.0  70.0
# 5              1443.0              1.0  70.0
# 6              1570.0              1.0  70.0
# 7              1031.0              1.0  70.0
# 8              1047.0              1.0  70.0
# 9              1052.0              1.0  70.0
#
#                                           PLACE NAME ZIP CODE
# 0  Wick Road, Allen Park, Wayne County, Michigan,...    48101
# 1  Vine Avenue, Allen Park, Wayne County, Michiga...    48101
# 2  Wick Road, Allen Park, Wayne County, Michigan,...    48101
# 3  Wick Road, Allen Park, Wayne County, Michigan,...    48101
# 4  Wick Road, Allen Park, Wayne County, Michigan,...    48101
# 5  Wick Road, Allen Park, Wayne County, Michigan,...    48101
# 6  Rosedale Boulevard, Allen Park, Wayne County, ...    48101
# 7  Wick Road, Allen Park, Wayne County, Michigan,...    48101
# 8  Wick Road, Allen Park, Wayne County, Michigan,...    48101
# 9  Hubert Avenue, Allen Park, Wayne County, Michi...    48101

# %% [markdown]
# Attempts to run either of the two functions on the entire dataset were unsuccessful and ended with the notebook hanging and requiring the kernel to be restarted
